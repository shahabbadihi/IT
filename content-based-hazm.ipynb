# %% [markdown]
# <a href="https://colab.research.google.com/github/shahabbadihi/IT/blob/master/content-based-hazm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import pandas as pd
import requests
import io

file_url = "https://raw.githubusercontent.com/shahabbadihi/IT/master/PreprocessedDataset2.csv"
response = requests.get(file_url)

dest = 'local-file.csv'

with open(dest, "wb") as filee:
  filee.write(response.content)

df = pd.read_csv(dest)
df=df.fillna('')
df.head(74998)
# Out:
#        product_id                                      product_title title_en  \
# 0          559850                   خاک و کود تی تی بسته 10 کیلوگرمی       TC
# 1          112946                               توستر فلر مدل TO 220       HA
# 2          607671       هدست واقعیت مجازی ایکس پی پروداکت مدل VR BOX       AC
# 3          757892                       کیف پول زنانه آیسا مدل KZP-1       FA
# 4          601446  اسپیکر قابل حمل مدل ip085 مناسب برای  آیفون و ...       IT
# ...           ...                                                ...      ...
# 74993      329655           کفش راحتی  زنانه لی نینگ مدل Bubble Face       FA
# 74994      624592                           فندک  مدادی واته 8021005       HW
# 74995      222488                        اسپیکر مارلی مدل CHANT MINI       IT
# 74996       48802                        نرم افزار جامع جاوا اسکریپت       MA
# 74997      616748  فیلامنت پرینتر سه بعدی PLA جامقه 1.75 میلی متر...       IT
#
#        user_id  likes  dislikes verification_status        recommend  \
# 0       466132      2         0            verified  not_recommended
# 1       466139      2         0            verified  not_recommended
# 2       466160      1         2            verified          no_idea
# 3       466160      1         0            verified  not_recommended
# 4       466160      2         2            verified          no_idea
# ...        ...    ...       ...                 ...              ...
# 74993  7093994      0         0            verified               \N
# 74994  7094033      1         0            verified               \N
# 74995  7094148      0         1            verified               \N
# 74996  7094364      0         0            verified          no_idea
# 74997  7094450      2         1            verified               \N
#
#                                  title  \
# 0                خاک عاری از مواد مقوی
# 1            خراب شدن اهرم پایین برنده
# 2         قیمت پایین فدای  کیفیت .....
# 3                     کیفیت ساخت پایین
# 4      بدرد ساختن اسپیکر پرتابل میخوره
# ...                                ...
# 74993                       حتما بخرید
# 74994                   ارزش خرید داره
# 74995               عالی پیشنهاد میکنم
# 74996             خواب میره ادم به خدا
# 74997                          فیلامنت
#
#                                                  comment  \
# 0      اصلا خاک خوبی نبود. کلی سنگ های درشت داشت و اص...
# 1      بعد از دو و نیم سال استفاده، اهرم پایین دهنده ...
# 2      کیفیت لنزش پایینه شرکت فروشنده گارانتی تعویض ن...
# 3      اصلا با قیمت فروش ویژه هم ارزش خرید نداره_x000...
# 4      دوستان من این مدل برای ساخت اسپیکر پرتابل گرفت...
# ...                                                  ...
# 74993  درسته قیمتش زیاده ولی کیفیتش عالیه _x000D_\nمن...
# 74994  خودتون باید ابتکار داشته باشید کمی ارتقاش بدید...
# 74995  واقعا خیلی خوبه الان ربیق هارمن کاردن خیلی خوب...
# 74996  وقتی داره آموزش میده خواب میری  به نظرم که خوب...
# 74997               نسبت به قیمت فیلامنت کیفیت خوبی دارد
#
#                                               advantages  \
# 0                                              ["ندارد"]
# 1                  ["زیبایی، سبکی و اندازه مناسب توستر"]
# 2                                              ["ارزون"]
# 3
# 4      ["کیفیت قابل قبول برد و آمپیلی فایر داخلی\r","...
# ...                                                  ...
# 74993
# 74994                     ["خوش دسته برای جوش های ظریف"]
# 74995                                    ["کیفیت بالا "]
# 74996
# 74997
#
#                                            disadvantages  cart_id
# 0                                    ["پر از سنگ ریزه "]        1
# 1                          ["خراب شدن اهرم پایین برنده"]        2
# 2                                    ["کیفیت پایین لنز"]        3
# 3         ["کیفیت ساخت پایین\r","چسب کاری داخل و بیرون"]        3
# 4                                      ["نداشتن بلوتوث"]        3
# ...                                                  ...      ...
# 74993                                                       74993
# 74994                      ["نازل سوختش راحت خراب میشه"]    74995
# 74995                                           ["هیچی"]    74996
# 74996  ["کند بودن تایپ\r","کند بودن اموزش\r","ضعیف بو...    74997
# 74997                                                       74998
#
# [74998 rows x 13 columns]

# %%
# !pip install hazm
from pandas.core.frame import DataFrame
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import re
import random
from scipy.sparse import csr_matrix
from __future__ import unicode_literals
from hazm import *

dff = DataFrame()
dff["user_id"] = df["user_id"]
dff["product_id"]= df["product_id"]
dff["content"] = df["comment"].str.cat(df["advantages"], sep = "-").str.cat(df["disadvantages"], sep = "-").str.cat(df["title"], sep = "-").str.cat(df["product_title"], sep = "-")


dff['content'].head(100)
stemmer = Stemmer()
for i in range(99999):
  dff.loc[[i]].content= stemmer.stem (dff.loc[[i]].content)
dff['content'].head(100)
# file_url = "https://raw.githubusercontent.com/shahabbadihi/IT/master/fa_stop_words.txt"
# response = requests.get(file_url)

# stop_words = []
# with open("stopwords.txt", "wb") as filee:
#   filee.write(response.content)

# with open("stopwords.txt", "r") as filee:  
#   for line in filee:
#     stop_words.append(line)
# stop_words = set(stop_words)

# tf = TfidfVectorizer(analyzer='word',ngram_range=(1,3),min_df=0, stop_words=stop_words)
# tfidf_matrix = tf.fit_transform(dff.loc[0:100000, 'content'].values.astype('U'))

# prtin(tfidf_matrix)
# Out:
#   File "<ipython-input-26-ee7d7edef520>", line 36
#     # tfidf_matrix = tf.fit_transform(dff.loc[0:100000, 'content'].values.astype('U'))
#                                                                                       ^
# SyntaxError: unexpected EOF while parsing

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-82b39b2fd3bd> in <module>()
#       1 for i in range(99999):
# ----> 2   dff.loc[[i]].content.str= stemmer.stem ( word_tokenize(dff.loc[[i]].content.str))
#       3 dff['content'].head(100)
#       4 # lemmatizer = Lemmatizer()
#       5 # lemmatizer.lemmatize ( 'می روم' )
#
# /usr/local/lib/python3.7/dist-packages/hazm/__init__.py in word_tokenize(sentence)
#      36         if not hasattr(word_tokenize, 'tokenizer'):
#      37                 word_tokenize.tokenizer = WordTokenizer()
# ---> 38         return word_tokenize.tokenizer.tokenize(sentence)
#
# /usr/local/lib/python3.7/dist-packages/hazm/WordTokenizer.py in tokenize(self, text)
#     109                         text = self.number_float_pattern.sub(self.number_float_repl, text)
#     110
# --> 111                 text = self.pattern.sub(r' \1 ', text.replace('\n', ' ').replace('\t', ' '))
#     112
#     113                 tokens = [word for word in text.split(' ') if word]
#
# TypeError: expected string or bytes-like object

# %%
def recommendations(index):
  cos_sim = (cosine_similarity(tfidf_matrix[index],tfidf_matrix))
  x=int( df.loc[[index]].product_id)
  for i in range(99999):
    if (int(df.loc[[i]].product_id )==x):
      cos_sim[0][i] = 0
  sorted_sim = pd.Series(cos_sim[0]).sort_values(ascending = False)
  print(sorted_sim)
  top_10 = list(sorted_sim.iloc[1:11].index)
  return top_10

recommendations(500)
# Out:
# 20767    0.177860
# 8782     0.166282
# 65723    0.105555
# 99472    0.090629
# 5252     0.085681
#            ...
# 23994    0.000000
# 87502    0.000000
# 17143    0.000000
# 43747    0.000000
# 26279    0.000000
# Length: 100000, dtype: float64
# [8782, 65723, 99472, 5252, 23944, 39244, 82859, 8745, 9523, 87135]

# %%
import random
likes= 0
for i in range(3):
  random_number=random.randint(0,100000)
  print('عنوان کالا:')
  print(df.loc[[random_number]].product_title)
  print('عناوین کالا های پیشنهادی : ')
  for recommend in recommendations(random_number):
    print(df.loc[[recommend]].product_title)
  print('از چه تعداد از پیشنهادات رضایت داشتید ؟ ')
  likes = likes + int(input())
print ('recall is: ' + str(likes/30))
# Out:
# عنوان کالا:
# 46070    زیر لیوانی تهران جی اف ایکس مدل ZL3223 بسته 6 ...
# Name: product_title, dtype: object
# عناوین کالا های پیشنهادی :
# 34318    0.360162
# 42121    0.235503
# 78518    0.209225
# 33824    0.184274
# 94419    0.170624
#            ...
# 50099    0.000000
# 50097    0.000000
# 50090    0.000000
# 84391    0.000000
# 4760     0.000000
# Length: 100000, dtype: float64
# 42121    زیر لیوانی تهران جی اف ایکس مدل ZL3209 بسته 6 ...
# Name: product_title, dtype: object
# 78518    جاشمعی تهران جی اف ایکس مدل JA5029
# Name: product_title, dtype: object
# 33824    جاشمعی تهران جی اف ایکس مدل JA5021
# Name: product_title, dtype: object
# 94419    جاشمعی تهران جی اف ایکس مدل JA5043
# Name: product_title, dtype: object
# 42128    جعبه دستمال کاغذی تهران جی اف ایکس مدل DT-9906
# Name: product_title, dtype: object
# 37130    جعبه دستمال کاغذی تهران جی اف ایکس مدل DT-9901
# Name: product_title, dtype: object
# 29312    پایه نگهدارنده موبایل و تبلت تهران جی اف ایکس ...
# Name: product_title, dtype: object
# 54300    جعبه دستمال کاغذی تهران جی اف ایکس مدل DT-9917
# Name: product_title, dtype: object
# 98698    ماوس پد تهران جی اف ایکس مدل MPS2026
# Name: product_title, dtype: object
# 46063    جعبه دستمال کاغذی تهران جی اف ایکس مدل DT-9911
# Name: product_title, dtype: object
# از چه تعداد از پیشنهادات رضایت داشتید ؟
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     726         """
# --> 727         parts = [self.recv(flags, copy=copy, track=track)]
#     728         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-d6eac72a99a8> in <module>()
#       9     print(df.loc[[recommend]].product_title)
#      10   print('از چه تعداد از پیشنهادات رضایت داشتید ؟ ')
# ---> 11   likes = likes + int(input())
#      12 print ('recall is: ' + str(likes/30))
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:
