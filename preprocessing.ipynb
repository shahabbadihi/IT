# %%
import sklearn
import pandas as pd
import requests
import io

file_url = "https://raw.githubusercontent.com/shahabbadihi/IT/master/2-p9vcb5bb.xlsx"
response = requests.get(file_url)

dest = 'local-file.xlsx'

with open(dest, "wb") as filee:
  filee.write(response.content)

df = pd.read_excel(dest)

df.head(100)
# Out:
#     product_id                                      product_title title_en  \
# 0         3692                        ماوس بی‌سیم لاجیتک مدل M325       IT
# 1        90213  شارژر همراه شیاومی مدل NDY-02-AN با ظرفیت 1000...       AC
# 2        59473              یدک پولیشر میکروفایبر مهسان مدل 20119       HW
# 3       120499   گوشی موبایل هوآوی آنر مدل 5X KIW-L21 دو سیم‌کارت       MO
# 4        67200  شارژر همراه شیائومی مدل Mi ظرفیت 5000 میلی آمپ...       AC
# ..         ...                                                ...      ...
# 95      163713                       میکروسکوپ سولومارک مدل HM900       AV
# 96      147614                       شارژر فندکی ریمکس مدل RCC303       AC
# 97       56736                       دریل چکشی بوش مدل PSB 530 RE       TC
# 98      189665                           کالسکه ارابه مدل Stripes       TS
# 99       90575  هارد اکسترنال سیلیکون پاور مدل Armor A65 ظرفیت...       IT
#
#     user_id  likes  dislikes verification_status        recommend  \
# ...

# %%
df.nunique()
# Out:
# product_id             50235
# product_title          49798
# title_en                  18
# user_id                56692
# likes                    151
# dislikes                 139
# verification_status        3
# recommend                  4
# title                  53057
# comment                96051
# advantages             32128
# disadvantages          23290
# dtype: int64

# %%
df.groupby('user_id').count().sort_values(by=['product_id'])
# Out:
#          product_id  product_title  title_en  likes  dislikes  \
# user_id
# 466132            1              1         1      1         1
# 6357235           1              1         1      1         1
# 6357452           1              1         1      1         1
# 6357627           1              1         1      1         1
# 6357729           1              1         1      1         1
# ...             ...            ...       ...    ...       ...
# 535912           94             94        94     94        94
# 2870189          97             97        97     97        97
# 4964994         154            154       154    154       154
# 1152044         182            182       182    182       182
# 764992          265            265       265    265       265
#
#          verification_status  recommend  title  comment  advantages  \
# user_id
# 466132                     1          1      1        1           1
# ...

# %%
tdf = df
tdf['cart_id'] = 0
tdf.head(100)
# Out:
#     product_id                                      product_title title_en  \
# 0         3692                        ماوس بی‌سیم لاجیتک مدل M325       IT
# 1        90213  شارژر همراه شیاومی مدل NDY-02-AN با ظرفیت 1000...       AC
# 2        59473              یدک پولیشر میکروفایبر مهسان مدل 20119       HW
# 3       120499   گوشی موبایل هوآوی آنر مدل 5X KIW-L21 دو سیم‌کارت       MO
# 4        67200  شارژر همراه شیائومی مدل Mi ظرفیت 5000 میلی آمپ...       AC
# ..         ...                                                ...      ...
# 95      163713                       میکروسکوپ سولومارک مدل HM900       AV
# 96      147614                       شارژر فندکی ریمکس مدل RCC303       AC
# 97       56736                       دریل چکشی بوش مدل PSB 530 RE       TC
# 98      189665                           کالسکه ارابه مدل Stripes       TS
# 99       90575  هارد اکسترنال سیلیکون پاور مدل Armor A65 ظرفیت...       IT
#
#     user_id  likes  dislikes verification_status        recommend  \
# ...

# %%
userid_list = tdf.user_id.unique().tolist()
print(userid_list[:10])
# Out:
# [989472, 3862150, 626843, 786887, 854531, 497032, 574130, 1139954, 2764879, 3934937]

# %%
import numpy as np

cartid_start = 1
# number = 0
# product_id 0, user_id 3, cart_id 12

for userid in sorted(userid_list):
    # for idx, row in tdf.iterrows():
    selected_user_rows = tdf[ tdf['user_id'] == userid ]

    # print(len(selected_user_rows))
    len_user_rows = len(selected_user_rows)
    next_user_cartid_start = cartid_start + len_user_rows;

    if (cartid_start == next_user_cartid_start - 1):
        arr_rand_cartids = [cartid_start]
    else:
        np.random.seed(0)
        arr_rand_cartids = [np.random.randint(low=cartid_start,
                                         high=next_user_cartid_start - 1,
                                         )] * len_user_rows
    
    tdf.loc[ tdf['user_id'] == userid, 'cart_id'] = arr_rand_cartids
    # if selected_user_rows[3] == user:
    #     row[12] = cart_id
    #     number += 1
    #     if number == 10:
    #         cart_id += 1
    #         number = 0
    # tdf[ tdf['user_id'] == userid ] = selected_user_rows


    cartid_start = next_user_cartid_start
    # number = 0

# %%
# df.loc[1:10, ['user_id', 'product_id', 'cart_id']].sort_values(by=['user_id'])
# df.sort_values(by=['user_id'])
df_with_cartids = df.loc[ : , ['user_id', 'product_id', 'cart_id']]
df_with_cartids.nsmallest(50, 'user_id')
# Out:
#        user_id  product_id  cart_id
# 21420   466132      559850        1
# 49610   466139      112946        2
# 33905   466160      607671        3
# 33907   466160      601446        3
# 36217   466160      757892        3
# 86273   466160      174874        3
# 57413   466168      694521        7
# 75519   466314      117324        8
# 81186   466314      593146        8
# 79172   466315      300411       10
# 64317   466348      316534       11
# 23370   466356      481583       12
# 86639   466384      621388       13
# 93575   466384      252377       13
# 19343   466387      687974       15
# 8727    466410      552127       16
# 42612   466413       37288       17
# 62418   466444      416559       18
# 87011   466444      549647       18
# 41950   466521      159242       20
# 10935   466523      734992       21
# 28218   466523      727590       21
# 78984   466543      478745       23
# 53276   466548      160203       24
# 81885   466589      591747       25
# ...

# %%
df.loc[df['user_id'] == 497032, ['user_id', 'product_id', 'cart_id']].sort_values(by=['user_id'])
# Out:
#        user_id  product_id  cart_id
# 5       497032      133722      968
# 22517   497032      475821      968

# %%
df.sort_values(by=['user_id']).to_csv('PreprocessedDataset.csv', index=False)
dff = pd.read_csv('PreprocessedDataset.csv')
dff.head(100)
# Out:
#     product_id                                      product_title title_en  \
# 0       559850                   خاک و کود تی تی بسته 10 کیلوگرمی       TC
# 1       112946                               توستر فلر مدل TO 220       HA
# 2       607671       هدست واقعیت مجازی ایکس پی پروداکت مدل VR BOX       AC
# 3       757892                       کیف پول زنانه آیسا مدل KZP-1       FA
# 4       601446  اسپیکر قابل حمل مدل ip085 مناسب برای  آیفون و ...       IT
# ..         ...                                                ...      ...
# 95      600404                   زیرپوش مردانه آستین کوتاه کد 002       FA
# 96      106164  چسب‌ پاک کننده بینی پیوردرم مدل Deep Cleansing...       PC
# 97      251989                 کیف دوربین ونگارد مدل Alta Rise 38       AV
# 98      311053  ادو تویلت مردانه داویدوف مدل Cool Water Pacifi...       PC
# 99      224848           کفپوش سه بعدی خودرو بابل مناسب برای تیبا       TC
#
#     user_id  likes  dislikes verification_status        recommend  \
# ...

# %%
# !git init
# !git config --global user.email "badihi2000@gmail.com"
# !git config --global user.name "shahabbadihi"

# !git remote add origin https://shahabbadihi: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@github.com/shahabbadihi/IT.git

# !git add PreprocessedDataset.csv
# !git commit -m "dataset with cart id"
# !git pull --rebase origin master
# !git push -u origin master

# !git remote rm origin
# Out:
# rebase in progress; onto c94a8e5
# You are currently rebasing branch 'master' on 'c94a8e5'.
#
# nothing to commit, working tree clean
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://shahabbadihi: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@github.com/shahabbadihi/IT.git/'

# %%
import numpy as np

print([2]*2)

print([np.random.randint(1, 3)]*3)
# Out:
# [2, 2]
# [1, 1, 1]
