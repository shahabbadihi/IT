# %% [markdown]
# <a href="https://colab.research.google.com/github/shahabbadihi/IT/blob/master/content-based2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import pandas as pd
import requests
import io

file_url = "https://raw.githubusercontent.com/shahabbadihi/IT/master/PreprocessedDataset.csv"
response = requests.get(file_url)

dest = 'local-file.csv'

with open(dest, "wb") as filee:
  filee.write(response.content)

df = pd.read_csv(dest)
df=df.fillna('')
df.head(8501)
# Out:
#       product_id                                      product_title title_en  \
# 0         559850                   خاک و کود تی تی بسته 10 کیلوگرمی       TC
# 1         112946                               توستر فلر مدل TO 220       HA
# 2         607671       هدست واقعیت مجازی ایکس پی پروداکت مدل VR BOX       AC
# 3         757892                       کیف پول زنانه آیسا مدل KZP-1       FA
# 4         601446  اسپیکر قابل حمل مدل ip085 مناسب برای  آیفون و ...       IT
# ...          ...                                                ...      ...
# 8496      619087  کارت گرافیک اینوتریدی مدل ICHILL GEFORCE GTX 1...       IT
# 8497      334883                            کارواش ایزی جت مدل 1001       TC
# 8498      581391          پولوشرت نخی مردانه سی اند ای مدل T-CA-004       FA
# 8499      555134                    پایه نگهدارنده اپل واچ مدل S330       AC
# 8500      186493                       کارواش هیوندای مدل HP1846-PW       TC
#
#       user_id  likes  dislikes verification_status        recommend  \
# 0      466132      2         0            verified  not_recommended
# 1      466139      2         0            verified  not_recommended
# 2      466160      1         2            verified          no_idea
# 3      466160      1         0            verified  not_recommended
# 4      466160      2         2            verified          no_idea
# ...       ...    ...       ...                 ...              ...
# 8496   759152      2         1            verified      recommended
# 8497   759280      4         0            verified  not_recommended
# 8498   759333      1         1            verified  not_recommended
# 8499   759345      1         0            verified               \N
# 8500   759345      3         3            verified               \N
#
#                                 title  \
# 0               خاک عاری از مواد مقوی
# 1           خراب شدن اهرم پایین برنده
# 2        قیمت پایین فدای  کیفیت .....
# 3                    کیفیت ساخت پایین
# 4     بدرد ساختن اسپیکر پرتابل میخوره
# ...                               ...
# 8496                            عالیه
# 8497                  ارزش خرید نداره
# 8498           کیفیت و تن خورش داغونه
# 8499           پایه نگهدارنده اپل واچ
# 8500
#
#                                                 comment  \
# 0     اصلا خاک خوبی نبود. کلی سنگ های درشت داشت و اص...
# 1     بعد از دو و نیم سال استفاده، اهرم پایین دهنده ...
# 2     کیفیت لنزش پایینه شرکت فروشنده گارانتی تعویض ن...
# 3     اصلا با قیمت فروش ویژه هم ارزش خرید نداره_x000...
# 4     دوستان من این مدل برای ساخت اسپیکر پرتابل گرفت...
# ...                                                 ...
# 8496  من اینو با دو دلی خریدم _x000D_\nخیلی تحقیق کر...
# 8497  سلام دوستان_x000D_\nدر حد یه آبپاش تفنگی (از ا...
# 8498                                 نخرید پشیمون میشید
# 8499                پایه خوبیه و خریدش رو پیشنهاد میکنم
# 8500                                         فوق العاده
#
#                                              advantages  \
# 0                                             ["ندارد"]
# 1                 ["زیبایی، سبکی و اندازه مناسب توستر"]
# 2                                             ["ارزون"]
# 3
# 4     ["کیفیت قابل قبول برد و آمپیلی فایر داخلی\r","...
# ...                                                 ...
# 8496
# 8497
# 8498                                          ["ندارد"]
# 8499
# 8500
#
#                                        disadvantages  cart_id
# 0                                ["پر از سنگ ریزه "]        1
# 1                      ["خراب شدن اهرم پایین برنده"]        2
# 2                                ["کیفیت پایین لنز"]        3
# 3     ["کیفیت ساخت پایین\r","چسب کاری داخل و بیرون"]        3
# 4                                  ["نداشتن بلوتوث"]        4
# ...                                              ...      ...
# 8496                                                     8497
# 8497                                                     8498
# 8498                                        ["زیاد"]     8499
# 8499                                                     8501
# 8500                                                     8501
#
# [8501 rows x 13 columns]

# %%
from pandas.core.frame import DataFrame
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import re
import random
from scipy.sparse import csr_matrix

dff = DataFrame()
dff["user_id"] = df["user_id"]
dff["product_id"]= df["product_id"]
dff["content"] = df["comment"].str.cat(df["advantages"], sep = "-").str.cat(df["disadvantages"], sep = "-").str.cat(df["title"], sep = "-").str.cat(df["product_title"], sep = "-")


dff.head(100)

file_url = "https://raw.githubusercontent.com/shahabbadihi/IT/master/fa_stop_words.txt"
response = requests.get(file_url)

stop_words = []
with open("stopwords.txt", "wb") as filee:
  filee.write(response.content)

with open("stopwords.txt", "r") as filee:  
  for line in filee:
    stop_words.append(line)
stop_words = set(stop_words)

df_samples = []
# cos_sim=[]


# dff.set_index('product_id',inplace=True)

df_samples = []

# for i in range(2):

#   df_samples.append( dff.sample(n = int(len(dff) / 10)) )
  
tf = TfidfVectorizer(analyzer='word',ngram_range=(1,3),min_df=0, stop_words=stop_words)
  
  # tfidf_matrices = []
  
# tfidf_matrix = tf.fit_transform(df_samples.loc['content'].values.astype('U'))
tfidf_matrix = tf.fit_transform(dff.loc[0:10000, 'content'].values.astype('U'))

  # print(tfidf_matrix)
cos_sim1 = (cosine_similarity(tfidf_matrix,tfidf_matrix))
  # print(type(cos_sim1))

  # dic = {}
  # for idx in df_samples.index:
  #   dic[idx] = cos_sim1[]
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:401: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['آباد', 'آخ', 'آخر', 'آخرها', 'آخه', 'آدمهاست', 'آرام', 'آره', 'آری', 'آزادانه', 'آسان', 'آسانی', 'آسیب', 'آشنایند', 'آشکارا', 'آقا', 'آقای', 'آقایان', 'آمد', 'آمدن', 'آمده', 'آمرانه', 'آن', 'آنان', 'آنانی', 'آنجا', 'آنرا', 'آنطور', 'آنقدر', 'آنكه', 'آنها', 'آنهاست', 'آنچنان', 'آنچه', 'آنکه', 'آنگاه', 'آهان', 'آهای', 'آور', 'آورد', 'آوردن', 'آورده', 'آوه', 'آيد', 'آی', 'آیا', 'آید', 'آیند', 'اتفاقا', 'اثر', 'اجراست', 'احتراما', 'احتمالا', 'احیانا', 'اخیر', 'اخیرا', 'اری', 'از', 'ازاین', 'ازجمله', 'ازش', 'اساسا', 'است', 'استفاد', 'استفاده', 'اسلامی', 'اش', 'اشتباها', 'اشکارا', 'اصلا', 'اصولا', 'اطلاعند', 'اعلام', 'اغلب', 'افزود', 'افسوس', 'اقل', 'اقلیت', 'اكنون', 'الا', 'الاسف', 'الان', 'البت', 'البته', 'الظاهر', 'الهی', 'الی', 'ام', 'اما', 'امروز', 'امروزه', 'امسال', 'امشب', 'امور', 'امیدوارم', 'امیدوارند', 'امیدواریم', 'ان', 'انتها', 'انجام', 'اند', 'اندکی', 'انشاالله', 'انصافا', 'انطور', 'انقدر', 'انها', 'انچنان', 'انکه', 'انگار', 'او', 'اوست', 'اول', 'اولا', 'اولین', 'اون', 'اي', 'ايشان', 'ايم', 'اين', 'اينكه', 'اکثر', 'اکثرا', 'اکثریت', 'اکنون', 'اگر', 'اگرچه', 'اگه', 'ای', 'ایا', 'اید', 'ایشان', 'ایم', 'این', 'اینان', 'اینجا', 'اینجاست', 'ایند', 'اینطور', 'اینقدر', 'اینها', 'اینهاست', 'اینو', 'اینچنین', 'اینک', 'اینکه', 'اینگونه', 'با', 'بااین', 'باد', 'بار', 'بارة', 'باره', 'بارها', 'باز', 'بازهم', 'بازی', 'بازیگوشانه', 'باش', 'باشد', 'باشم', 'باشند', 'باشيم', 'باشی', 'باشید', 'باشیم', 'بالا', 'بالاخره', 'بالاخص', 'بالاست', 'بالای', 'بالطبع', 'بالعکس', 'باوجودی', 'باورند', 'بايد', 'باید', 'بتدریج', 'بتوان', 'بتواند', 'بتوانی', 'بتوانیم', 'بجز', 'بخش', 'بخشه', 'بخشی', 'بخصوص', 'بخواه', 'بخواهد', 'بخواهم', 'بخواهند', 'بخواهی', 'بخواهید', 'بخواهیم', 'بخوبی', 'بد', 'بدان', 'بدانجا', 'بدانها', 'بدهید', 'بدون', 'بدین', 'بدینجا', 'بر', 'برآن', 'برآنند', 'برا', 'برابر', 'براحتی', 'براساس', 'براستی', 'براي', 'برای', 'برایت', 'برایش', 'برایشان', 'برایم', 'برایمان', 'برخوردار', 'برخوردارند', 'برخي', 'برخی', 'برداري', 'برداری', 'برعکس', 'برنامه', 'بروز', 'بروشنی', 'بزرگ', 'بزودی', 'بس', 'بسا', 'بسادگی', 'بسته', 'بسختی', 'بسوی', 'بسيار', 'بسياري', 'بسی', 'بسیار', 'بسیاری', 'بشدت', 'بطور', 'بطوری', 'بعد', 'بعدا', 'بعدازظهر', 'بعدها', 'بعری', 'بعضا', 'بعضي', 'بعضی', 'بعضیهایشان', 'بعلاوه', 'بعید', 'بفهمی', 'بلافاصله', 'بلكه', 'بله', 'بلکه', 'بلی', 'بماند', 'بنابراين', 'بنابراین', 'بندي', 'بندی', 'به', 'بهت', 'بهتر', 'بهترين', 'بهترین', 'بهش', 'بود', 'بودم', 'بودن', 'بودند', 'بوده', 'بودی', 'بودید', 'بودیم', 'بویژه', 'بي', 'بيست', 'بيش', 'بيشتر', 'بيشتري', 'بين', 'بپا', 'بکار', 'بکن', 'بکند', 'بکنم', 'بکنند', 'بکنی', 'بکنید', 'بکنیم', 'بگذاریم', 'بگو', 'بگوید', 'بگویم', 'بگویند', 'بگویی', 'بگویید', 'بگوییم', 'بگیر', 'بگیرد', 'بگیرم', 'بگیرند', 'بگیری', 'بگیرید', 'بگیریم', 'بی', 'بیا', 'بیاب', 'بیابد', 'بیابم', 'بیابند', 'بیابی', 'بیابید', 'بیابیم', 'بیاور', 'بیاورد', 'بیاورم', 'بیاورند', 'بیاوری', 'بیاورید', 'بیاوریم', 'بیاید', 'بیایم', 'بیایند', 'بیایی', 'بیایید', 'بیاییم', 'بیرون', 'بیست', 'بیش', 'بیشتر', 'بیشتری', 'بین', 'بیگمان', 'تا', 'تازه', 'تازگی', 'تاكنون', 'تان', 'تاکنون', 'تحت', 'تحریم', 'تدریج', 'تر', 'ترتیب', 'تردید', 'ترند', 'ترين', 'تریلیارد', 'تریلیون', 'ترین', 'تصریحا', 'تعدادی', 'تعمدا', 'تفاوتند', 'تقریبا', 'تلویحا', 'تمام', 'تماما', 'تمامشان', 'تمامي', 'تمامی', 'تند', 'تنها', 'تو', 'توؤما', 'توان', 'تواند', 'توانست', 'توانستم', 'توانستن', 'توانستند', 'توانسته', 'توانستی', 'توانستیم', 'توانم', 'توانند', 'توانی', 'توانید', 'توانیم', 'توسط', 'تول', 'توی', 'تک', 'تی', 'ثالثا', 'ثانی', 'ثانیا', 'جا', 'جاي', 'جايي', 'جای', 'جایی', 'جدا', 'جداگانه', 'جديد', 'جدید', 'جدیدا', 'جرمزاست', 'جريان', 'جریان', 'جز', 'جلو', 'جلوگيري', 'جلوگیری', 'جلوی', 'جمع', 'جمعا', 'جمعی', 'جمله', 'جنابعالی', 'جناح', 'جنس', 'جهت', 'جور', 'جوری', 'حاشیه', 'حاضر', 'حاضرم', 'حال', 'حالا', 'حاکیست', 'حتما', 'حتي', 'حتی', 'حداقل', 'حداکثر', 'حدود', 'حدودا',  ...
#   % sorted(inconsistent)

# %%
# type(cos_sim)

sorted_sim = pd.Series(cos_sim1[8500]).sort_values(ascending = False)
top_10 = list(sorted_sim.iloc[1:11].index)
top_10
# cos_sim1
# Out:
# [4411, 5309, 4096, 2537, 3846, 4021, 3412, 3034, 7096, 5730]
