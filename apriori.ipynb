# %% [markdown]
# <a href="https://colab.research.google.com/github/shahabbadihi/IT/blob/master/apriori.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import requests
import io

file_url = "https://raw.githubusercontent.com/shahabbadihi/IT/master/SentimentDataset.csv"
response = requests.get(file_url)

dest = 'local-file.csv'

with open(dest, "wb") as filee:
  filee.write(response.content)

df = pd.read_csv(dest)
df.head(10)
# Out:
#    Unnamed: 0  product_id                                      product_title  \
# 0           0      559850                   خاک و کود تی تی بسته 10 کیلوگرمی
# 1           1      112946                               توستر فلر مدل TO 220
# 2           2      607671       هدست واقعیت مجازی ایکس پی پروداکت مدل VR BOX
# 3           3      757892                       کیف پول زنانه آیسا مدل KZP-1
# 4           4      601446  اسپیکر قابل حمل مدل ip085 مناسب برای  آیفون و ...
# 5           5      174874              دسته بازی بلوتوث شیاومی مدل MDZ-11-AA
# 6           6      694521          تیله شیشه ای کیان مدل پنج پر بسته 20 عددی
# 7           7      593146            کفش راحتی زنانه مل اند موژ مدل W-1102-1
# 8           8      117324          کیف دستی چرم طبیعی گالری چیستا طرح اسلیمی
# 9           9      300411                 کفش راحتی مردانه ژرمن مدل k.na.761
#
#   title_en  user_id  likes  dislikes verification_status        recommend  \
# 0       TC   466132      2         0            verified  not_recommended
# 1       HA   466139      2         0            verified  not_recommended
# 2       AC   466160      1         2            verified          no_idea
# 3       FA   466160      1         0            verified  not_recommended
# 4       IT   466160      2         2            verified          no_idea
# 5       AV   466160      0         0            verified               \N
# 6       TS   466168      0         0            verified  not_recommended
# 7       FA   466314      6         3            verified      recommended
# 8       MA   466314      1         0            verified      recommended
# 9       FA   466315      0         0            verified               \N
#
#                              title  \
# 0            خاک عاری از مواد مقوی
# 1        خراب شدن اهرم پایین برنده
# 2     قیمت پایین فدای  کیفیت .....
# 3                 کیفیت ساخت پایین
# 4  بدرد ساختن اسپیکر پرتابل میخوره
# 5              بهترین گیم پد موجود
# 6                   پشیمان از خرید
# 7           واقعا می ارزه من راضیم
# 8                        کیف خوبیه
# 9             عدم وجود سایز بزرگتر
#
#                                              comment  \
# 0  اصلا خاک خوبی نبود. کلی سنگ های درشت داشت و اص...
# 1  بعد از دو و نیم سال استفاده، اهرم پایین دهنده ...
# 2  کیفیت لنزش پایینه شرکت فروشنده گارانتی تعویض ن...
# 3  اصلا با قیمت فروش ویژه هم ارزش خرید نداره_x000...
# 4  دوستان من این مدل برای ساخت اسپیکر پرتابل گرفت...
# 5  بهترین گیم پدی که استفاده کردم_x000D_\nتو خرید...
# 6  فکر میکردم بزرتر از این باشد و شفافتر ولی کئچک...
# 7                             تو تخفیف خریدش می ارزه
# 8  سلام من این کیفو واسه خانومم خریدم همه چیزش خو...
# 9                  متاسفانه فقط سایز کوچک موجود است!
#
#                                           advantages  \
# 0                                          ["ندارد"]
# 1              ["زیبایی، سبکی و اندازه مناسب توستر"]
# 2                                          ["ارزون"]
# 3                                                NaN
# 4  ["کیفیت قابل قبول برد و آمپیلی فایر داخلی\r","...
# 5  ["ارگونومی ps4\r","چینش xBOX360\r","کیفیت ساخت...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                     ["عالی وزیبا"]
#
#                                        disadvantages  cart_id  \
# 0                                ["پر از سنگ ریزه "]        1
# 1                      ["خراب شدن اهرم پایین برنده"]        2
# 2                                ["کیفیت پایین لنز"]        3
# 3     ["کیفیت ساخت پایین\r","چسب کاری داخل و بیرون"]        3
# 4                                  ["نداشتن بلوتوث"]        4
# 5  ["شارژی نبودن\r","نیاز به برنامه برای اتصال به...        4
# 6                        ["عدم تشابه عکس با واقعیت"]        7
# 7                                                NaN        8
# 8                                                NaN        8
# 9                                      ["سایز کوچک"]       10
#
#    comment_sentiment
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# 5                  1
# 6                  1
# 7                  1
# 8                  1
# 9                  1

# %%
# for idx, row in df.iterrows():
    
# df.groupby('cart_id').size()

df = df[['user_id', 'product_id', 'product_title', 'cart_id']]
unique_cartids = df.cart_id.unique()
list_carts_df = []

for cartid in unique_cartids:

    list_carts_df.append( df[ df['cart_id'] == cartid ] )

# %%
dic_carts = {}

for cart in list_carts_df:
    cart_id = cart[['cart_id']].values.tolist()[0][0]
    # print((cart_id))
    # break
    dic_carts[cart_id] = []
    cart2 = cart[['product_id']]
    products = cart2.values.tolist()
    
    for p in products:
       dic_carts[cart_id].append(p[0])
    # print(products)
    # break

print(dic_carts)
# Out:
# {1: [559850], 2: [112946], 3: [607671, 757892], 4: [601446, 174874], 7: [694521], 8: [593146, 117324], 10: [300411], 11: [316534], 12: [481583], 13: [621388, 252377], 15: [687974], 16: [552127], 17: [37288], 18: [416559, 549647], 20: [159242], 21: [734992, 727590], 23: [478745], 24: [160203], 25: [591747], 26: [144891], 27: [270383], 28: [511078], 29: [134558], 30: [127453], 31: [186962, 450608], 33: [770182], 34: [409019], 35: [88684], 36: [637676, 321761], 38: [331125], 39: [31617], 42: [168934], 46: [441662], 49: [563348], 45: [75114, 147165], 47: [790118, 487660], 44: [315744], 40: [468260], 43: [597114, 612667, 146476], 53: [559855], 55: [155162, 502004], 52: [481237, 173533], 57: [300411], 58: [601741], 59: [620497], 65: [167472], 73: [851807], 61: [112957], 74: [282953], 67: [24775, 22914], 60: [223032], 63: [570846, 127470], 66: [146847, 201873], 72: [141243, 570852], 64: [250377], 78: [130234], 79: [206138], 69: [204366, 447321], 77: [197266], 75: [694644], 80: [571802], 68: [338095], 83: [170904, 86141], 82: [78606], 85: [349274], 86: [391639, 743181], 88: [531462], 89: [564383], 90: [749114], 91: [693250], 92: [190022], 93: [461745], 96: [495729, 106164, 251989], 94: [135764], 98: [600404], 97: [311053], 100: [224848], 101: [444